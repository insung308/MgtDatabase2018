# %% [markdown]
# ## 서울 지역 유가가 특히 비싸 자세히 알아 보고자
# ## 서울 지역만 따로 결과 분석을 해 보았습니다.

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/지역*.xls')
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
stations_files=glob('../data/지역*.xls')
stations_files
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
tmp_raw=[]

for file_name in stations_files:
    tmp=pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw=pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 523 entries, 0 to 42
# Data columns (total 10 columns):
# 지역       523 non-null object
# 상호       523 non-null object
# 주소       523 non-null object
# 상표       523 non-null object
# 전화번호     523 non-null object
# 셀프여부     523 non-null object
# 고급휘발유    523 non-null object
# 휘발유      523 non-null object
# 경유       523 non-null object
# 실내등유     523 non-null object
# dtypes: object(10)
# memory usage: 44.9+ KB

# %%
station_raw.head()
# Out:
#    지역                상호                      주소      상표         전화번호 셀프여부  \
# 0  서울            구천면주유소   서울 강동구 구천면로 357 (암사동)  현대오일뱅크  02-441-0536    N
# 1  서울  주)지유에너지직영 오렌지주유소   서울 강동구  성안로 102 (성내동)   SK에너지  02-484-6165    N
# 2  서울    GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)   GS칼텍스  02-475-2600    N
# 3  서울             광성주유소   서울 강동구 올림픽로 673 (천호동)   S-OIL  02-470-5133    N
# 4  서울    대성석유(주)직영길동주유소  서울 강동구 천호대로 1168 (둔촌동)   GS칼텍스  02-474-7222    N
#
#   고급휘발유   휘발유    경유  실내등유
# 0     -  1566  1365     -
# 1     -  1568  1368  1047
# 2  1885  1569  1369  1020
# 3     -  1588  1388     -
# 4  1877  1598  1398  1000

# %%
stations=pd.DataFrame({'Oil_store':station_raw['상호'],
                       '주소':station_raw['주소'],
                       '가격':station_raw['휘발유'],
                       '셀프':station_raw['셀프여부'],
                       '상표':station_raw['상표']})
stations.head()
# Out:
#           Oil_store                      주소    가격 셀프      상표
# 0            구천면주유소   서울 강동구 구천면로 357 (암사동)  1566  N  현대오일뱅크
# 1  주)지유에너지직영 오렌지주유소   서울 강동구  성안로 102 (성내동)  1568  N   SK에너지
# 2    GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)  1569  N   GS칼텍스
# 3             광성주유소   서울 강동구 올림픽로 673 (천호동)  1588  N   S-OIL
# 4    대성석유(주)직영길동주유소  서울 강동구 천호대로 1168 (둔촌동)  1598  N   GS칼텍스

# %%
stations['구']=[eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#           Oil_store                      주소    가격 셀프      상표    구
# 0            구천면주유소   서울 강동구 구천면로 357 (암사동)  1566  N  현대오일뱅크  강동구
# 1  주)지유에너지직영 오렌지주유소   서울 강동구  성안로 102 (성내동)  1568  N   SK에너지  강동구
# 2    GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)  1569  N   GS칼텍스  강동구
# 3             광성주유소   서울 강동구 올림픽로 673 (천호동)  1588  N   S-OIL  강동구
# 4    대성석유(주)직영길동주유소  서울 강동구 천호대로 1168 (둔촌동)  1598  N   GS칼텍스  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations['구']=='서울특별시']
# Out:
# Empty DataFrame
# Columns: [Oil_store, 주소, 가격, 셀프, 상표, 구]
# Index: []

# %%
stations.loc[stations['구']=='서울특별시', '구']=='성동구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations['구']=='특별시']
# Out:
# Empty DataFrame
# Columns: [Oil_store, 주소, 가격, 셀프, 상표, 구]
# Index: []

# %%
stations.loc[stations['구']=='특별시','구']=='도봉구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations['가격']=='-']
# Out:
#         Oil_store                       주소 가격 셀프     상표     구
# 18  명진석유(주)동서울주유소  서울 강동구  천호대로 1456 (상일동)  -  Y  GS칼텍스   강동구
# 13          서강주유소     서울 마포구 독막로 134 (창전동)  -  N  SK에너지   마포구
# 25          목동주유소    서울 양천구 목동중앙로 125 (목동)  -  N  S-OIL   양천구
# 34          하나주유소   서울 영등포구  도림로 236 (신길동)  -  N  S-OIL  영등포구
# 12   (주)에이앤이청담주유소    서울 강북구 도봉로 155  (미아동)  -  Y  SK에너지   강북구
# 13          새한주유소     서울 강북구  도봉로 75 (미아동)  -  Y  SK에너지   강북구
# 34        하이웨이주유소    서울 강서구 공항대로 432 (화곡동)  -  N  S-OIL   강서구

# %%
stations=stations[stations['가격']!='-']
stations.head()
# Out:
#           Oil_store                      주소    가격 셀프      상표    구
# 0            구천면주유소   서울 강동구 구천면로 357 (암사동)  1566  N  현대오일뱅크  강동구
# 1  주)지유에너지직영 오렌지주유소   서울 강동구  성안로 102 (성내동)  1568  N   SK에너지  강동구
# 2    GS칼텍스㈜직영 신월주유소  서울 강동구 양재대로 1323 (성내동)  1569  N   GS칼텍스  강동구
# 3             광성주유소   서울 강동구 올림픽로 673 (천호동)  1588  N   S-OIL  강동구
# 4    대성석유(주)직영길동주유소  서울 강동구 천호대로 1168 (둔촌동)  1598  N   GS칼텍스  강동구

# %%
stations['가격']=[float(value) for value in stations['가격']]

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
# Oil_store    516 non-null object
# 주소           516 non-null object
# 가격           516 non-null float64
# 셀프           516 non-null object
# 상표           516 non-null object
# 구            516 non-null object
# dtypes: float64(1), object(5)
# memory usage: 24.3+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path="c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system()=='Darwin':
    rc('font', family='AppleGothic')
elif platform.system()=='Windows':
    font_name=font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system.. sorry~~~~')

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12,8));

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", data=stations, color=".6")
plt.show()

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
stations.sort_values(by="가격", ascending=False).head(10)
# Out:
#           Oil_store                      주소      가격 셀프     상표    구
# 315           서남주유소    서울 중구 통일로 30 (봉래동1가)  2217.0  N  SK에너지   중구
# 314           장충주유소  서울 중구 장충단로 202 (장충동1가)  2213.0  N  SK에너지   중구
# 120           양재주유소   서울 서초구 바우뫼로 178 (양재동)  2212.0  N  SK에너지  서초구
# 515         뉴서울(강남)    서울 강남구 언주로 716 (논현동)  2180.0  N  SK에너지  강남구
# 313           필동주유소   서울 중구  퇴계로 196 (필동2가)  2169.0  N  GS칼텍스   중구
# 275            한남지점  서울 용산구 한남대로21길 4 (한남동)  2148.0  N  SK에너지  용산구
# 302  (주)중앙에너비스혜화주유소  서울 종로구 창경궁로35길 1 (혜화동)  2148.0  N  SK에너지  종로구
# 303        (주)대양씨앤씨     서울 종로구 사직로 65 (사직동)  2148.0  N  GS칼텍스  종로구
# 312  주)중앙에너비스 퇴계로지점   서울 중구  퇴계로 228 (필동2가)  2148.0  N  SK에너지   중구
# 276            에너비스  서울 용산구 한남대로21길 4 (한남동)  2148.0  N  SK에너지  용산구

# %%
stations.sort_values(by='가격', ascending=True).head(10)
# Out:
#              Oil_store                       주소      가격 셀프      상표     구
# 334          강서오곡셀프주유소     서울 강서구 벌말로 254 (오곡동)  1498.0  Y   SK에너지   강서구
# 277  (주)명연에너지 수색훼미리주유소     서울 은평구 수색로 236 (수색동)  1503.0  Y  현대오일뱅크   은평구
# 278             타이거주유소     서울 은평구 수색로 188 (증산동)  1504.0  Y   SK에너지   은평구
# 455   한이에너지(주)KLP제1주유소     서울 도봉구  도봉로 596 (창동)  1507.0  N  현대오일뱅크   도봉구
# 216              도림주유소    서울 영등포구 도림로 343 (도림동)  1508.0  Y   알뜰주유소  영등포구
# 218           (주)블루에너지  서울 영등포구  가마산로 367 (대림동)  1508.0  Y   SK에너지  영등포구
# 219            (주)강서오일    서울 영등포구 도신로 151 (도림동)  1508.0  N  현대오일뱅크  영등포구
# 220           (주)MS주유소    서울 영등포구 대림로 230 (대림동)  1508.0  N  현대오일뱅크  영등포구
# 217     (주)대청에너지 대청주유소   서울 영등포구 가마산로 328 (대림동)  1508.0  N   GS칼텍스  영등포구
# 456              쌍문주유소    서울 도봉구  도봉로 547 (쌍문동)  1509.0  Y   S-OIL   도봉구

# %%
import numpy as np
gu_data=pd.pivot_table(stations, index=["구"], values=["가격"],
                      aggfunc=np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1818.279070
# 강동구  1653.944444
# 강북구  1544.166667
# 강서구  1585.117647
# 관악구  1611.411765

# %%
geo_path='../data/02. skorea_municipalities_geo_simple.json'
geo_data=json.load(open(geo_path, encoding='utf-8'))

map=folium.Map(location=[37.5502, 126.982], zoom_start=10.5,
              tiles='Stamen Toner')
map.choropleth(geo_data=geo_data,
              data=gu_data,
              columns=[gu_data.index, '가격'],
              fill_color='PuRd', #Purd, Y1GnBu
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10=stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#           Oil_store                      주소      가격 셀프     상표    구
# 315           서남주유소    서울 중구 통일로 30 (봉래동1가)  2217.0  N  SK에너지   중구
# 314           장충주유소  서울 중구 장충단로 202 (장충동1가)  2213.0  N  SK에너지   중구
# 120           양재주유소   서울 서초구 바우뫼로 178 (양재동)  2212.0  N  SK에너지  서초구
# 515         뉴서울(강남)    서울 강남구 언주로 716 (논현동)  2180.0  N  SK에너지  강남구
# 313           필동주유소   서울 중구  퇴계로 196 (필동2가)  2169.0  N  GS칼텍스   중구
# 275            한남지점  서울 용산구 한남대로21길 4 (한남동)  2148.0  N  SK에너지  용산구
# 302  (주)중앙에너비스혜화주유소  서울 종로구 창경궁로35길 1 (혜화동)  2148.0  N  SK에너지  종로구
# 303        (주)대양씨앤씨     서울 종로구 사직로 65 (사직동)  2148.0  N  GS칼텍스  종로구
# 312  주)중앙에너비스 퇴계로지점   서울 중구  퇴계로 228 (필동2가)  2148.0  N  SK에너지   중구
# 276            에너비스  서울 용산구 한남대로21길 4 (한남동)  2148.0  N  SK에너지  용산구

# %%
oil_price_bottom10=stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#              Oil_store                       주소      가격 셀프      상표     구
# 334          강서오곡셀프주유소     서울 강서구 벌말로 254 (오곡동)  1498.0  Y   SK에너지   강서구
# 277  (주)명연에너지 수색훼미리주유소     서울 은평구 수색로 236 (수색동)  1503.0  Y  현대오일뱅크   은평구
# 278             타이거주유소     서울 은평구 수색로 188 (증산동)  1504.0  Y   SK에너지   은평구
# 455   한이에너지(주)KLP제1주유소     서울 도봉구  도봉로 596 (창동)  1507.0  N  현대오일뱅크   도봉구
# 216              도림주유소    서울 영등포구 도림로 343 (도림동)  1508.0  Y   알뜰주유소  영등포구
# 218           (주)블루에너지  서울 영등포구  가마산로 367 (대림동)  1508.0  Y   SK에너지  영등포구
# 219            (주)강서오일    서울 영등포구 도신로 151 (도림동)  1508.0  N  현대오일뱅크  영등포구
# 220           (주)MS주유소    서울 영등포구 대림로 230 (대림동)  1508.0  N  현대오일뱅크  영등포구
# 217     (주)대청에너지 대청주유소   서울 영등포구 가마산로 328 (대림동)  1508.0  N   GS칼텍스  영등포구
# 456              쌍문주유소    서울 도봉구  도봉로 547 (쌍문동)  1509.0  Y   S-OIL   도봉구

# %%
gmap_key="AIzaSyBKWuN3qGoolo0s1NykG0Ahk4gvuaWKBxs"
gmaps=googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#           Oil_store                      주소      가격 셀프     상표    구        lat  \
# 315           서남주유소    서울 중구 통일로 30 (봉래동1가)  2217.0  N  SK에너지   중구  37.558348
# 314           장충주유소  서울 중구 장충단로 202 (장충동1가)  2213.0  N  SK에너지   중구  37.562719
# 120           양재주유소   서울 서초구 바우뫼로 178 (양재동)  2212.0  N  SK에너지  서초구  37.478071
# 515         뉴서울(강남)    서울 강남구 언주로 716 (논현동)  2180.0  N  SK에너지  강남구  37.517636
# 313           필동주유소   서울 중구  퇴계로 196 (필동2가)  2169.0  N  GS칼텍스   중구  37.560850
# 275            한남지점  서울 용산구 한남대로21길 4 (한남동)  2148.0  N  SK에너지  용산구  37.534657
# 302  (주)중앙에너비스혜화주유소  서울 종로구 창경궁로35길 1 (혜화동)  2148.0  N  SK에너지  종로구  37.586068
# 303        (주)대양씨앤씨     서울 종로구 사직로 65 (사직동)  2148.0  N  GS칼텍스  종로구  37.574464
# 312  주)중앙에너비스 퇴계로지점   서울 중구  퇴계로 228 (필동2가)  2148.0  N  SK에너지   중구  37.561648
# 276            에너비스  서울 용산구 한남대로21길 4 (한남동)  2148.0  N  SK에너지  용산구  37.534657
#
#             lng
# 315  126.972090
# 314  127.007010
# 120  127.039610
# 515  127.035756
# 313  126.993653
# 275  127.006063
# 302  127.001058
# 303  126.966618
# 312  126.997142
# 276  127.006063

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
    
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#              Oil_store                       주소      가격 셀프      상표     구  \
# 334          강서오곡셀프주유소     서울 강서구 벌말로 254 (오곡동)  1498.0  Y   SK에너지   강서구
# 277  (주)명연에너지 수색훼미리주유소     서울 은평구 수색로 236 (수색동)  1503.0  Y  현대오일뱅크   은평구
# 278             타이거주유소     서울 은평구 수색로 188 (증산동)  1504.0  Y   SK에너지   은평구
# 455   한이에너지(주)KLP제1주유소     서울 도봉구  도봉로 596 (창동)  1507.0  N  현대오일뱅크   도봉구
# 216              도림주유소    서울 영등포구 도림로 343 (도림동)  1508.0  Y   알뜰주유소  영등포구
# 218           (주)블루에너지  서울 영등포구  가마산로 367 (대림동)  1508.0  Y   SK에너지  영등포구
# 219            (주)강서오일    서울 영등포구 도신로 151 (도림동)  1508.0  N  현대오일뱅크  영등포구
# 220           (주)MS주유소    서울 영등포구 대림로 230 (대림동)  1508.0  N  현대오일뱅크  영등포구
# 217     (주)대청에너지 대청주유소   서울 영등포구 가마산로 328 (대림동)  1508.0  N   GS칼텍스  영등포구
# 456              쌍문주유소    서울 도봉구  도봉로 547 (쌍문동)  1509.0  Y   S-OIL   도봉구
#
#            lat         lng
# 334  37.555284  126.768567
# 277  37.581122  126.897774
# 278  37.578424  126.902050
# 455  37.657714  127.040569
# 216  37.507656  126.900191
# 218  37.501567  126.898791
# 219  37.509969  126.908231
# 220  37.501330  126.897403
# 217  37.498556  126.895791
# 456  37.653949  127.037515

# %%
map = folium.Map(location=[37.5202, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
                                  radius=15, color='#CD3181', 
                                  fill_color='#CD3181',
                                  fill=True).add_to(map)
    
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]): 
        folium.CircleMarker([oil_price_bottom10['lat'][n], 
                                  oil_price_bottom10['lng'][n]], 
                                  radius=15, color='#3186cc', 
                                  fill_color='#3186cc',
                                  fill=True).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
